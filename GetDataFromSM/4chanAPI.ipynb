# %%
import requests
import pandas as pd
import time

# %%
def get_threads(key, thread, default='NaN'):
    return thread.get(key, default)

def get_all_threads():
    r = requests.get('https://a.4cdn.org/pol/catalog.json')
    r = r.json()
    
    data = []
    
    for page in r:
        threads = page['threads']
        
        for thread in threads:
            no = get_threads('no', thread)
            com = get_threads('com', thread)
            time = get_threads('time', thread)
            
            data.append({
                'id': no,
                'comment': com,
                'date': pd.to_datetime(time, unit='s')
            })
    
    return pd.DataFrame(data)

# %%
df = get_all_threads()
df.to_csv('../Data/4chan/pol_4chan_comments.csv', index=False, sep=';')
df
# Out:
#             id                                            comment  \
# 0    124205675  This board is for the discussion of news, worl...
# 1    259848258  <p style="font-size:22px;font-weight:600;">Che...
# 2    435024099  <span class="quote">&gt;bridge blown up for a ...
# 3    435022551  So at no point during filming did you think to...
# 4    435014144  timothy simpkins is currently on trial. the pr...
# ..         ...                                                ...
# 197  435018027  Are you excited for the film? That&#039;s me o...
# 198  435014764  The following songs were all massive hits in t...
# 199  435019767  Any nation that puts into practice the right t...
# 200  435017384     Is there anything more pathetic than working??
# 201  434996981     Why do travelers have more liberal worldviews?
#
#                    date
# 0   2017-05-05 14:07:06
# 1   2020-05-31 19:07:39
# 2   2023-07-19 15:53:43
# 3   2023-07-19 15:36:33
# 4   2023-07-19 13:57:06
# ..                  ...
# 197 2023-07-19 14:45:52
# 198 2023-07-19 14:05:21
# 199 2023-07-19 15:05:49
# 200 2023-07-19 14:38:01
# 201 2023-07-19 09:35:39
#
# [202 rows x 3 columns]

# %% [markdown]
# # Extract over a number of comments

# %%
def get_4chan_comments(limit):
    run_loop = True

    while run_loop:
        df = pd.read_csv('../Data/4chan/pol_4chan_comments.csv', sep=';')
        
        df_new = pd.concat([df, get_all_threads()])
        df_new = df_new.drop_duplicates()
        
        df_new.to_csv('../Data/4chan/pol_4chan_comments.csv', index=False, sep=';')
        
        if len(df_new) >= limit:
            run_loop = False
        
        time.sleep(30)

# %%
get_4chan_comments(10000)

# %%
df = pd.read_csv('../Data/4chan/pol_4chan_comments.csv', sep=';')
df
# Out:
#             id                                            comment  \
# 0    124205675  This board is for the discussion of news, worl...
# 1    259848258  <p style="font-size:22px;font-weight:600;">Che...
# 2    435024099  <span class="quote">&gt;bridge blown up for a ...
# 3    435022551  So at no point during filming did you think to...
# 4    435014144  timothy simpkins is currently on trial. the pr...
# ..         ...                                                ...
# 411  435010664         You! Show me your based home library, NOW!
# 412  435017650  So we all laughed at zoomers for the tide pod ...
# 413  435011688  <span class="quote">&gt;Russia is now mobilisi...
# 414  435009272  Will you live in a 3D printed house?<br><br>- ...
# 415  435014312  I&#039;m a member of the Crete branch of the S...
#
#                     date
# 0    2017-05-05 14:07:06
# 1    2020-05-31 19:07:39
# 2    2023-07-19 15:53:43
# 3    2023-07-19 15:36:33
# 4    2023-07-19 13:57:06
# ..                   ...
# 411  2023-07-19 13:09:25
# 412  2023-07-19 14:40:59
# 413  2023-07-19 13:23:46
# 414  2023-07-19 12:49:34
# 415  2023-07-19 13:59:16
#
# [416 rows x 3 columns]
